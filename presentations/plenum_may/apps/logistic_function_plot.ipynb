# %%
using Plots

# %%
p=-5:0.01:5
r=map(x->1/(1+exp(-x)),p)
plot(p,r,xlim=[-5,5],ylim=[0,1],xlab="popularity  p / p₀",ylab="request frequency  r / rₘₐₓ",frame=:box,legend=:none)

# %%
savefig("logistic_function.png")
